# %%
print("hello, world!")
# Out:
# hello, world!

# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi

# Initialize the Kaggle API
api = KaggleApi()
api.authenticate()

# Specify the dataset you want to download
dataset = "jahnavipaliwal/field-of-study-vs-occupation"

# Specify the download path
download_path = "/Users/michaelgyimadu/machine-learning/ml-playground/datasets/field_of_study_vs_occupation"

# Create the directory if it doesn't exist
os.makedirs(download_path, exist_ok=True)

# Download and unzip the dataset
api.dataset_download_files(dataset, path=download_path, unzip=True)

print(f"Dataset downloaded and extracted to: {os.path.abspath(download_path)}")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/jahnavipaliwal/field-of-study-vs-occupation
# Dataset downloaded and extracted to: /Users/michaelgyimadu/machine-learning/ml-playground/datasets/field_of_study_vs_occupation

# %%
import pandas as pd
import os

def load_data(DOWNLOAD_PATH=download_path):
    csv_path = os.path.join(download_path, "career_change_prediction_dataset.csv")
    return pd.read_csv(csv_path)

career_change = load_data()
career_change.head()
# Out:
#   Field of Study Current Occupation  Age  Gender  Years of Experience  \
# 0       Medicine   Business Analyst   48    Male                    7
# 1      Education          Economist   44    Male                   26
# 2      Education          Biologist   21  Female                   27
# 3      Education   Business Analyst   33    Male                   14
# 4           Arts             Doctor   28  Female                    0
#
#   Education Level Industry Growth Rate  Job Satisfaction  Work-Life Balance  \
# 0     High School                 High                 7                 10
# 1        Master's                  Low                10                  3
# 2        Master's                  Low                 8                  3
# 3             PhD               Medium                 7                  9
# 4             PhD                  Low                 3                  1
#
#    Job Opportunities  ...  Skills Gap  Family Influence  Mentorship Available  \
# ...

# %%
print("Column names:", career_change.columns.tolist())
# Out:
# Column names: ['Field of Study', 'Current Occupation', 'Age', 'Gender', 'Years of Experience', 'Education Level', 'Industry Growth Rate', 'Job Satisfaction', 'Work-Life Balance', 'Job Opportunities', 'Salary', 'Job Security', 'Career Change Interest', 'Skills Gap', 'Family Influence', 'Mentorship Available', 'Certifications', 'Freelancing Experience', 'Geographic Mobility', 'Professional Networks', 'Career Change Events', 'Technology Adoption', 'Likely to Change Occupation']

# %%
career_change.select_dtypes(include=['object']).value_counts()
# Out:
# Field of Study    Current Occupation  Gender  Education Level  Industry Growth Rate  Family Influence
# Medicine          Doctor              Male    High School      Medium                Medium              14
# Computer Science  Biologist           Male    Bachelor's       Medium                Low                 13
# Medicine          Psychologist        Male    High School      High                  Medium              13
# Psychology        Psychologist        Female  Master's         Low                   High                13
# Arts              Teacher             Male    PhD              Low                   Medium              13
#                                                                                                          ..
# Psychology        Business Analyst    Female  High School      High                  Medium               1
# Education         Biologist           Female  High School      Medium                Medium               1
# ...

# %%
career_change.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38444 entries, 0 to 38443
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Field of Study               38444 non-null  object
#  1   Current Occupation           38444 non-null  object
#  2   Age                          38444 non-null  int64
#  3   Gender                       38444 non-null  object
#  4   Years of Experience          38444 non-null  int64
#  5   Education Level              38444 non-null  object
#  6   Industry Growth Rate         38444 non-null  object
#  7   Job Satisfaction             38444 non-null  int64
#  8   Work-Life Balance            38444 non-null  int64
#  9   Job Opportunities            38444 non-null  int64
#  10  Salary                       38444 non-null  int64
#  11  Job Security                 38444 non-null  int64
#  12  Career Change Interest       38444 non-null  int64
# ...

# %%
career_change["Field of Study"].value_counts()
# Out:
# Field of Study
# Medicine                  3949
# Business                  3921
# Biology                   3921
# Education                 3896
# Mechanical Engineering    3875
# Law                       3851
# Computer Science          3826
# Arts                      3763
# Economics                 3743
# Psychology                3699
# Name: count, dtype: int64

# %%
career_change["Current Occupation"].value_counts()
# Out:
# Current Occupation
# Software Developer     3892
# Psychologist           3890
# Doctor                 3888
# Teacher                3886
# Artist                 3881
# Business Analyst       3858
# Mechanical Engineer    3827
# Lawyer                 3781
# Biologist              3774
# Economist              3767
# Name: count, dtype: int64

# %%
career_change.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38444 entries, 0 to 38443
# Data columns (total 23 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Field of Study               38444 non-null  object
#  1   Current Occupation           38444 non-null  object
#  2   Age                          38444 non-null  int64
#  3   Gender                       38444 non-null  object
#  4   Years of Experience          38444 non-null  int64
#  5   Education Level              38444 non-null  object
#  6   Industry Growth Rate         38444 non-null  object
#  7   Job Satisfaction             38444 non-null  int64
#  8   Work-Life Balance            38444 non-null  int64
#  9   Job Opportunities            38444 non-null  int64
#  10  Salary                       38444 non-null  int64
#  11  Job Security                 38444 non-null  int64
#  12  Career Change Interest       38444 non-null  int64
# ...

# %%
career_change.describe()
# Out:
#                 Age  Years of Experience  Job Satisfaction  Work-Life Balance  \
# count  38444.000000         38444.000000      38444.000000       38444.000000
# mean      39.540422            19.548200          5.489673           5.517012
# std       11.574509            11.552474          2.870407           2.879007
# min       20.000000             0.000000          1.000000           1.000000
# 25%       30.000000            10.000000          3.000000           3.000000
# 50%       40.000000            20.000000          6.000000           6.000000
# 75%       50.000000            30.000000          8.000000           8.000000
# max       59.000000            39.000000         10.000000          10.000000
#
#        Job Opportunities         Salary  Job Security  Career Change Interest  \
# count       38444.000000   38444.000000  38444.000000            38444.000000
# mean           50.308267  114975.623999      5.481896                0.199901
# ...

# %%
print(df.isnull().sum())
# Out:
# Field of Study                    0
# Current Occupation                0
# Age                               0
# Gender                            0
# Years of Experience               0
# Education Level                   0
# Industry Growth Rate              0
# Job Satisfaction                  0
# Work-Life Balance                 0
# Job Opportunities                 0
# Salary                            0
# Job Security                      0
# Career Change Interest            0
# Skills Gap                        0
# Family Influence               9632
# Mentorship Available              0
# Certifications                    0
# Freelancing Experience            0
# Geographic Mobility               0
# Professional Networks             0
# Career Change Events              0
# Technology Adoption               0
# Likely to Change Occupation       0
# dtype: int64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
career_change.hist(bins=50, figsize=(20,15))
plt.tight_layout()
plt.show()

# %%
occupation_counts = career_change["Current Occupation"].value_counts()
print("Occupation distribution:")
print(occupation_counts)
# Out:
# Occupation distribution:
# Current Occupation
# Software Developer     3892
# Psychologist           3890
# Doctor                 3888
# Teacher                3886
# Artist                 3881
# Business Analyst       3858
# Mechanical Engineer    3827
# Lawyer                 3781
# Biologist              3774
# Economist              3767
# Name: count, dtype: int64

# %%
for col in career_change.select_dtypes(include=['object']).columns:
    print(f"Unique values in {col}:")
    print(df[col].value_counts())
    print()
# Out:
# Unique values in Field of Study:
# Field of Study
# Medicine                  3949
# Business                  3921
# Biology                   3921
# Education                 3896
# Mechanical Engineering    3875
# Law                       3851
# Computer Science          3826
# Arts                      3763
# Economics                 3743
# Psychology                3699
# Name: count, dtype: int64
#
# Unique values in Current Occupation:
# Current Occupation
# Software Developer     3892
# Psychologist           3890
# Doctor                 3888
# Teacher                3886
# Artist                 3881
# Business Analyst       3858
# Mechanical Engineer    3827
# Lawyer                 3781
# Biologist              3774
# Economist              3767
# Name: count, dtype: int64
#
# Unique values in Gender:
# Gender
# Female    19299
# Male      19145
# Name: count, dtype: int64
#
# Unique values in Education Level:
# Education Level
# PhD            9777
# ...

# %%
corr_matrix = career_change_numeric.corr()
corr_matrix["Likely to Change Occupation"].sort_values(ascending=False)
# Out:
# Likely to Change Occupation    1.000000
# Career Change Interest         0.428367
# Work-Life Balance              0.005768
# Career Change Events           0.002825
# Certifications                 0.002320
# Skills Gap                     0.002096
# Job Opportunities              0.001047
# Geographic Mobility           -0.001098
# Freelancing Experience        -0.001641
# Professional Networks         -0.001835
# Years of Experience           -0.002004
# Technology Adoption           -0.002587
# Mentorship Available          -0.005082
# Age                           -0.005483
# Job Security                  -0.006496
# Salary                        -0.177951
# Job Satisfaction              -0.595550
# Name: Likely to Change Occupation, dtype: float64

# %%
from pandas.plotting import scatter_matrix

attributes = ["Likely to Change Occupation", "Career Change Interest", "Work-Life Balance", "Career Change Events"]
scatter_matrix(career_change[attributes], figsize=(12, 8))
# Out:
# array([[<Axes: xlabel='Likely to Change Occupation', ylabel='Likely to Change Occupation'>,
#         <Axes: xlabel='Career Change Interest', ylabel='Likely to Change Occupation'>,
#         <Axes: xlabel='Work-Life Balance', ylabel='Likely to Change Occupation'>,
#         <Axes: xlabel='Career Change Events', ylabel='Likely to Change Occupation'>],
#        [<Axes: xlabel='Likely to Change Occupation', ylabel='Career Change Interest'>,
#         <Axes: xlabel='Career Change Interest', ylabel='Career Change Interest'>,
#         <Axes: xlabel='Work-Life Balance', ylabel='Career Change Interest'>,
#         <Axes: xlabel='Career Change Events', ylabel='Career Change Interest'>],
#        [<Axes: xlabel='Likely to Change Occupation', ylabel='Work-Life Balance'>,
#         <Axes: xlabel='Career Change Interest', ylabel='Work-Life Balance'>,
#         <Axes: xlabel='Work-Life Balance', ylabel='Work-Life Balance'>,
# ...

# %%
for col in career_change.select_dtypes(include=['object']).columns:
    print(f"Unique values in {col}:")
    print(df[col].value_counts())
    print()
# Out:
# Unique values in Field of Study:
# Field of Study
# Medicine                  3949
# Business                  3921
# Biology                   3921
# Education                 3896
# Mechanical Engineering    3875
# Law                       3851
# Computer Science          3826
# Arts                      3763
# Economics                 3743
# Psychology                3699
# Name: count, dtype: int64
#
# Unique values in Current Occupation:
# Current Occupation
# Software Developer     3892
# Psychologist           3890
# Doctor                 3888
# Teacher                3886
# Artist                 3881
# Business Analyst       3858
# Mechanical Engineer    3827
# Lawyer                 3781
# Biologist              3774
# Economist              3767
# Name: count, dtype: int64
#
# Unique values in Gender:
# Gender
# Female    19299
# Male      19145
# Name: count, dtype: int64
#
# Unique values in Education Level:
# Education Level
# PhD            9777
# ...

# %%
career_change
# Out:
#                Field of Study   Current Occupation  Age  Gender  \
# 0                    Medicine     Business Analyst   48    Male
# 1                   Education            Economist   44    Male
# 2                   Education            Biologist   21  Female
# 3                   Education     Business Analyst   33    Male
# 4                        Arts               Doctor   28  Female
# ...                       ...                  ...  ...     ...
# 38439                 Biology     Business Analyst   24  Female
# 38440  Mechanical Engineering               Artist   21  Female
# 38441        Computer Science  Mechanical Engineer   35  Female
# 38442                    Arts     Business Analyst   35    Male
# 38443                     Law  Mechanical Engineer   37    Male
#
#        Years of Experience Education Level Industry Growth Rate  \
# 0                        7     High School                 High
# 1                       26        Master's                  Low
# ...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
career_change['Gender_Male'] = encoder.fit_transform(career_change['Gender'])
career_change.head()
# Out:
#   Field of Study Current Occupation  Age  Gender  Years of Experience  \
# 0       Medicine   Business Analyst   48    Male                    7
# 1      Education          Economist   44    Male                   26
# 2      Education          Biologist   21  Female                   27
# 3      Education   Business Analyst   33    Male                   14
# 4           Arts             Doctor   28  Female                    0
#
#   Education Level Industry Growth Rate  Job Satisfaction  Work-Life Balance  \
# 0     High School                 High                 7                 10
# 1        Master's                  Low                10                  3
# 2        Master's                  Low                 8                  3
# 3             PhD               Medium                 7                  9
# 4             PhD                  Low                 3                  1
#
#    Job Opportunities  ...  Family Influence  Mentorship Available  \
# ...

# %%
career_change = career_change.drop('Gender', axis=1)

# %%
career_change
# Out:
#                Field of Study   Current Occupation  Age  Years of Experience  \
# 0                    Medicine     Business Analyst   48                    7
# 1                   Education            Economist   44                   26
# 2                   Education            Biologist   21                   27
# 3                   Education     Business Analyst   33                   14
# 4                        Arts               Doctor   28                    0
# ...                       ...                  ...  ...                  ...
# 38439                 Biology     Business Analyst   24                   34
# 38440  Mechanical Engineering               Artist   21                   24
# 38441        Computer Science  Mechanical Engineer   35                   21
# 38442                    Arts     Business Analyst   35                   11
# 38443                     Law  Mechanical Engineer   37                   23
#
# ...

# %%
ordered_categories = ['Low', 'Medium', 'High']

career_change['Family Influence'] = pd.Categorical(career_change['Family Influence'], categories=ordered_categories, ordered=True)
career_change['Family Influence Encoded'] = career_change['Family Influence'].cat.codes

# %%
career_change
# Out:
#                Field of Study   Current Occupation  Age  Years of Experience  \
# 0                    Medicine     Business Analyst   48                    7
# 1                   Education            Economist   44                   26
# 2                   Education            Biologist   21                   27
# 3                   Education     Business Analyst   33                   14
# 4                        Arts               Doctor   28                    0
# ...                       ...                  ...  ...                  ...
# 38439                 Biology     Business Analyst   24                   34
# 38440  Mechanical Engineering               Artist   21                   24
# 38441        Computer Science  Mechanical Engineer   35                   21
# 38442                    Arts     Business Analyst   35                   11
# 38443                     Law  Mechanical Engineer   37                   23
#
# ...
